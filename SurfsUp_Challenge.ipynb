# %%
#import dependencies. 
# Canvas Lesson 9.1.3
from matplotlib import style
style.use('fivethirtyeight')
import matplotlib.pyplot as plt

# %%
# Dependencies lesson 9.1.3 Canvas
import numpy as np
import pandas as pd
import datetime as dt

# Python SQL toolkit and Object Relational Mapper
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func

# %%
# Create Engine. CanvasLesson 9.1.5
engine = create_engine("sqlite:///hawaii.sqlite")

# reflect an existing database into a new model
Base = automap_base()
# reflect the tables
Base.prepare(engine, reflect=True)

# Save references to each table
Measurement = Base.classes.measurement
Station = Base.classes.station

# %%
# Create our session (link) from Python to the DB. 
# Canvas Lesson 9.1.5
session = Session(engine)

# %% [markdown]
# ## D1: Determine the Summary Statistics for June

# %%
# 1. Import the sqlalchemy extract function. 
from sqlalchemy import extract

# 2. Write a query that filters the Measurement table to retrieve the temperatures for the month of June. 
# Instructor provide code in slack and I assigned it to an object -'06' = June, following Canvas example 9.2.1 
results_june_temps = session.query(Measurement.date, Measurement.tobs).\
    filter(extract('month', Measurement.date)=='06')
print(results_june_temps)
# Out:
# SELECT measurement.date AS measurement_date, measurement.tobs AS measurement_tobs
# FROM measurement
# WHERE CAST(STRFTIME('%m', measurement.date) AS INTEGER) = ?

# %%
#  3. Convert the June temperatures to a list. 
# Canvas Lesson 9.2.1
results_june_temps = session.query(Measurement.date, Measurement.tobs).\
    filter(extract('month', Measurement.date)=='06').all()
print(results_june_temps)
# Out:
# [('2010-06-01', 78.0), ('2010-06-02', 76.0), ('2010-06-03', 78.0), ('2010-06-04', 76.0), ('2010-06-05', 77.0), ('2010-06-06', 78.0), ('2010-06-07', 77.0), ('2010-06-08', 78.0), ('2010-06-09', 78.0), ('2010-06-10', 79.0), ('2010-06-11', 78.0), ('2010-06-12', 78.0), ('2010-06-13', 78.0), ('2010-06-14', 77.0), ('2010-06-15', 78.0), ('2010-06-16', 78.0), ('2010-06-17', 77.0), ('2010-06-18', 77.0), ('2010-06-19', 82.0), ('2010-06-20', 78.0), ('2010-06-21', 78.0), ('2010-06-22', 78.0), ('2010-06-23', 78.0), ('2010-06-24', 78.0), ('2010-06-25', 77.0), ('2010-06-26', 76.0), ('2010-06-27', 78.0), ('2010-06-28', 78.0), ('2010-06-29', 78.0), ('2010-06-30', 78.0), ('2011-06-01', 77.0), ('2011-06-02', 78.0), ('2011-06-03', 73.0), ('2011-06-04', 70.0), ('2011-06-05', 76.0), ('2011-06-06', 77.0), ('2011-06-07', 77.0), ('2011-06-08', 77.0), ('2011-06-09', 77.0), ('2011-06-10', 78.0), ('2011-06-11', 77.0), ('2011-06-12', 77.0), ('2011-06-13', 78.0), ('2011-06-14', 78.0), ('2011-06-15', 77.0), ('2011-
# ...

# %%
# 4. Create a DataFrame from the list of temperatures for the month of June. 
# Canvas Lesson 9.2.2 
df_june_temps = pd.DataFrame(results_june_temps, columns=['Date',"June Temperatures"])
print(df_june)
# Out:
#             Date  June Temperatures
# 0     2010-06-01               78.0
# 1     2010-06-02               76.0
# 2     2010-06-03               78.0
# 3     2010-06-04               76.0
# 4     2010-06-05               77.0
# ...          ...                ...
# 1695  2017-06-26               79.0
# 1696  2017-06-27               74.0
# 1697  2017-06-28               74.0
# 1698  2017-06-29               76.0
# 1699  2017-06-30               75.0
#
# [1700 rows x 2 columns]

# %%
# 5. Calculate and print out the summary statistics for the June temperature DataFrame.
# Canvas Section (9.2.5)
df_june.describe()
# Out:
#        June Temperatures
# count        1700.000000
# mean           74.944118
# std             3.257417
# min            64.000000
# 25%            73.000000
# 50%            75.000000
# 75%            77.000000
# max            85.000000

# %% [raw]
# ## D2: Determine the Summary Statistics for December

# %%
# 6. Write a query that filters the Measurement table to retrieve the temperatures for the month of December.
# Canvas Lesson 9.2.1, I copied the code from step 2 and change the month to December.
results_december_temps = session.query(Measurement.date, Measurement.tobs).\
    filter(extract('month', Measurement.date)=='12')
print(results_december_temps)
# Out:
# SELECT measurement.date AS measurement_date, measurement.tobs AS measurement_tobs
# FROM measurement
# WHERE CAST(STRFTIME('%m', measurement.date) AS INTEGER) = ?

# %%
# 7. Convert the December temperatures to a list.  
# I just copied the code from step 3 and changed the month from June to December

results_december_temps = session.query(Measurement.date, Measurement.tobs).\
    filter(extract('month', Measurement.date)=='12').all()
print(results_december_temps)
# Out:
# [('2010-12-01', 76.0), ('2010-12-03', 74.0), ('2010-12-04', 74.0), ('2010-12-06', 64.0), ('2010-12-07', 64.0), ('2010-12-08', 67.0), ('2010-12-09', 77.0), ('2010-12-10', 66.0), ('2010-12-11', 69.0), ('2010-12-12', 68.0), ('2010-12-13', 68.0), ('2010-12-14', 71.0), ('2010-12-15', 74.0), ('2010-12-16', 67.0), ('2010-12-17', 66.0), ('2010-12-18', 69.0), ('2010-12-19', 71.0), ('2010-12-23', 70.0), ('2010-12-24', 70.0), ('2010-12-26', 74.0), ('2010-12-27', 74.0), ('2010-12-28', 71.0), ('2010-12-29', 75.0), ('2010-12-30', 75.0), ('2010-12-31', 72.0), ('2011-12-01', 69.0), ('2011-12-02', 68.0), ('2011-12-03', 73.0), ('2011-12-04', 74.0), ('2011-12-05', 73.0), ('2011-12-06', 73.0), ('2011-12-07', 73.0), ('2011-12-08', 73.0), ('2011-12-09', 71.0), ('2011-12-10', 73.0), ('2011-12-11', 73.0), ('2011-12-12', 77.0), ('2011-12-13', 72.0), ('2011-12-14', 71.0), ('2011-12-15', 73.0), ('2011-12-16', 70.0), ('2011-12-17', 73.0), ('2011-12-18', 69.0), ('2011-12-19', 74.0), ('2011-12-20', 72.0), ('2011-
# ...

# %%
# 8. Create a DataFrame from the list of temperatures for the month of December. 
# I copied the code from step four and changed the month to December
df_december_temps = pd.DataFrame(results_december_temps, columns=['Date',"December Temperatures"])
print(df_december_temps)
# Out:
#             Date  December Temperatures
# 0     2010-12-01                   76.0
# 1     2010-12-03                   74.0
# 2     2010-12-04                   74.0
# 3     2010-12-06                   64.0
# 4     2010-12-07                   64.0
# ...          ...                    ...
# 1512  2016-12-27                   71.0
# 1513  2016-12-28                   71.0
# 1514  2016-12-29                   69.0
# 1515  2016-12-30                   65.0
# 1516  2016-12-31                   65.0
#
# [1517 rows x 2 columns]

# %%
# 9. Calculate and print out the summary statistics for the Decemeber temperature DataFrame.
# Canvas section 9.2.5. 

df_december_temps.describe()
# Out:
#        December Temperatures
# count            1517.000000
# mean               71.041529
# std                 3.745920
# min                56.000000
# 25%                69.000000
# 50%                71.000000
# 75%                74.000000
# max                83.000000

# %%
# Plots are not part of the chalenge I coded to the plot to be  added to my Readme
Canvas Lesson 9.3.4

df_december_temps.plot.hist(bins=12)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
# Plots are not part of the chalenge I coded the plot added to my Readme
# Canvas Lesson 9.3.4

df_june_temps.plot.hist(bins=12)
# Out:
# <AxesSubplot:ylabel='Frequency'>
